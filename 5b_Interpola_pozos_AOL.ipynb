# %% [markdown]
# #  <span style="color:#cc416d"> Interpola pozos, ahora al limite del acuifero </span>

# %%
import os
import numpy as np
import subprocess
import pandas as pd
import rasterio
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.ops import unary_union

os.environ["PATH"] += r";C:\OSGeo4W\bin"
subprocess.run(["gdal_grid", "--version"]) 
# 📌 Ruta del ejecutable de gdal_grid
gdal_grid_exe = r"C:\OSGeo4W\bin\gdal_grid.exe"
print ("\U0001F40D")
# Out:
# 🐍

# %% [markdown]
# ###  <span style="color:#cc416d"> Rutas </span>

# %%
path = "C:/Proyectos/2025/Armeria/"
os.chdir(path)
print ("Ruta de trabajo:   " + path)
carpeta_salida = r"C:/Proyectos/2025/Armeria/salidas/"
print("Salidas", carpeta_salida)
print ("\U0001F40D")
# Out:
# Ruta de trabajo:   C:/Proyectos/2025/Armeria/
# Salidas C:/Proyectos/2025/Armeria/salidas/
# 🐍

# %% [markdown]
# ###  <span style="color:#cc416d"> Lectura del csv </span>

# %%
df = pd.read_csv("Acuifero_Armeria.csv")
print ("\U0001F40D")
# Out:
# 🐍

# %%
df
# Out:
#     Pozo  Estado                     Acuífero  Elev.Brocal    Latitud  \
# 0     17  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         7.21  18.786667
# 1     29  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         9.11  18.813333
# 2     56  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        18.10  18.849722
# 3     60  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        13.28  18.839722
# 4     67  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        18.47  18.852500
# 5     71  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        10.23  18.801111
# 6     74  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        13.48  18.822500
# 7     78  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        16.69  18.838889
# 8     86  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        17.43  18.856944
# 9     95  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        20.89  18.876944
# 10   128  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS       250.23  19.178056
# 11   129  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS       255.51  19.187778
# 12   131  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS       274.16  19.203333
# 13   214  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        32.67  18.911667
# 14   219  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         6.20  18.863889
# 15   222  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        20.80  18.903611
# 16   238  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        46.42  18.940556
# 17   249  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        56.60  18.963611
# 18   252  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        98.96  18.989722
# 19   276  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        20.71  18.872778
# 20   294  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        12.71  18.853889
# 21   417  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        22.10  18.886944
# 22   450  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         7.80  18.845556
# 23   467  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        43.73  18.935833
# 24   470  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        36.39  18.922222
# 25   474  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        20.76  18.895000
# 26   501  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        28.70  18.936389
# 27   510  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         5.41  18.910833
# 28   515  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        28.32  18.933333
# 29   526  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        14.42  18.930000
# 30   544  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        16.38  18.910556
# 31   576  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        37.23  18.919722
# 32   581  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        65.18  18.975833
# 33   585  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        61.71  18.962222
# 34   587  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        49.10  18.950000
# 35   608  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        60.76  18.989722
# 36   612  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        61.35  18.989167
# 37   617  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        69.70  19.007500
# 38   621  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         5.87  18.828056
# 39   656  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        14.60  18.866944
# 40   731  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS       105.32  19.029722
# 41   736  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        89.18  19.013611
# 42   786  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        24.43  18.907222
# 43   854  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        40.73  18.796389
# 44   907  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS       118.39  19.043333
# 45   931  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        27.21  18.936944
# 46   968  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        22.22  18.760556
# 47  1020  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        26.80  18.883611
# 48  1040  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        48.50  18.946111
# 49  1122  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS       175.20  19.088333
# 50  1131  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        14.10  18.906111
# 51  1134  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        11.01  18.800278
# 52  1333  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        18.10  18.922222
# 53  1364  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        18.47  18.777222
# 54  1377  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        50.81  18.970278
# 55  1631  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         5.70  18.897500
# 56  1697  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS         6.20  18.768056
# 57  1840  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        50.17  18.935000
# 58  1962  Colima  ARMERÍA-TECOMÁN-PERIQUILLOS        12.63  18.831389
#
#       Longitud   1996  1997   1998  1999  ...  2016  2017  2018  2019  2020  \
# 0  -103.836944   3.10   NaN   1.92   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1  -103.861944   4.38   NaN   3.43   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 2  -103.828611    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 3  -103.860278   7.48   NaN   5.29   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 4  -103.833611  11.29   NaN   9.68   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 5  -103.782778   2.61   NaN   2.12   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 6  -103.806111   3.56   NaN   3.76   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 7  -103.794444    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 8  -103.815833    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 9  -103.785833   2.45   NaN   2.90   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 10 -103.922222    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 11 -103.925000    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 12 -103.927222    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 13 -103.833611   4.72   NaN   3.18   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 14 -103.951944    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 15 -103.859722   3.51   NaN   3.14   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 16 -103.867222   2.08   NaN   2.61   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 17 -103.847500  11.39   NaN   9.44   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 18 -103.837500  48.58   NaN  47.83   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 19 -103.857500   2.83   NaN   3.64   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 20 -103.886944   7.43   NaN   7.37   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 21 -103.893333   9.83   NaN  10.09   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 22 -103.913056    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 23 -103.951111  18.28   NaN  17.19   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 24 -103.915833  15.56   NaN  15.29   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 25 -103.935833    NaN   NaN  10.12   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 26 -104.028611    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 27 -104.022222    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 28 -103.969167    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 29 -103.997500    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 30 -103.987222    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 31 -103.888611  11.56   NaN  11.49   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 32 -103.885278    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 33 -103.877500   9.63   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 34 -103.896944    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 35 -103.953889    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 36 -103.982778    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 37 -103.978056    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 38 -103.896389   2.51   NaN   2.95   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 39 -103.922222    NaN   NaN   6.47   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 40 -103.982778    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 41 -104.001944    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 42 -103.789444   2.28   NaN   1.18   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 43 -103.727778    NaN   NaN  32.17   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 44 -103.998333    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 45 -103.933889   6.86   NaN   6.24   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 46 -103.728333    NaN   NaN  17.22   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 47 -103.813889    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 48 -103.919167    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 49 -103.882222    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 50 -103.964444    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 51 -103.817500   7.17   NaN   3.62   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 52 -103.944167    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 53 -103.754722    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 54 -103.926111    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 55 -104.003889    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 56 -103.795556    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 57 -103.833333    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 58 -103.838056    NaN   NaN    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#     2021  2022  2023  2024  2025
# 0    NaN   NaN   NaN   NaN   NaN
# 1    NaN   NaN   NaN   NaN   NaN
# 2    NaN   NaN   NaN   NaN   NaN
# 3    NaN   NaN   NaN   NaN   NaN
# 4    NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN   NaN   NaN
# 6    NaN   NaN   NaN   NaN   NaN
# 7    NaN   NaN   NaN   NaN   NaN
# 8    NaN   NaN   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN
# 10   NaN   NaN   NaN   NaN   NaN
# 11   NaN   NaN   NaN   NaN   NaN
# 12   NaN   NaN   NaN   NaN   NaN
# 13   NaN   NaN   NaN   NaN   NaN
# 14   NaN   NaN   NaN   NaN   NaN
# 15   NaN   NaN   NaN   NaN   NaN
# 16   NaN   NaN   NaN   NaN   NaN
# 17   NaN   NaN   NaN   NaN   NaN
# 18   NaN   NaN   NaN   NaN   NaN
# 19   NaN   NaN   NaN   NaN   NaN
# 20   NaN   NaN   NaN   NaN   NaN
# 21   NaN   NaN   NaN   NaN   NaN
# 22   NaN   NaN   NaN   NaN   NaN
# 23   NaN   NaN   NaN   NaN   NaN
# 24   NaN   NaN   NaN   NaN   NaN
# 25   NaN   NaN   NaN   NaN   NaN
# 26   NaN   NaN   NaN   NaN   NaN
# 27   NaN   NaN   NaN   NaN   NaN
# 28   NaN   NaN   NaN   NaN   NaN
# 29   NaN   NaN   NaN   NaN   NaN
# 30   NaN   NaN   NaN   NaN   NaN
# 31   NaN   NaN   NaN   NaN   NaN
# 32   NaN   NaN   NaN   NaN   NaN
# 33   NaN   NaN   NaN   NaN   NaN
# 34   NaN   NaN   NaN   NaN   NaN
# 35   NaN   NaN   NaN   NaN   NaN
# 36   NaN   NaN   NaN   NaN   NaN
# 37   NaN   NaN   NaN   NaN   NaN
# 38   NaN   NaN   NaN   NaN   NaN
# 39   NaN   NaN   NaN   NaN   NaN
# 40   NaN   NaN   NaN   NaN   NaN
# 41   NaN   NaN   NaN   NaN   NaN
# 42   NaN   NaN   NaN   NaN   NaN
# 43   NaN   NaN   NaN   NaN   NaN
# 44   NaN   NaN   NaN   NaN   NaN
# 45   NaN   NaN   NaN   NaN   NaN
# 46   NaN   NaN   NaN   NaN   NaN
# 47   NaN   NaN   NaN   NaN   NaN
# 48   NaN   NaN   NaN   NaN   NaN
# 49   NaN   NaN   NaN   NaN   NaN
# 50   NaN   NaN   NaN   NaN   NaN
# 51   NaN   NaN   NaN   NaN   NaN
# 52   NaN   NaN   NaN   NaN   NaN
# 53   NaN   NaN   NaN   NaN   NaN
# 54   NaN   NaN   NaN   NaN   NaN
# 55   NaN   NaN   NaN   NaN   NaN
# 56   NaN   NaN   NaN   NaN   NaN
# 57   NaN   NaN   NaN   NaN   NaN
# 58   NaN   NaN   NaN   NaN   NaN
#
# [59 rows x 36 columns]

# %% [markdown]
# ###  <span style="color:#cc416d"> Proyección </span>

# %%
# ---- 1) Pasar puntos a GeoDataFrame en grados NAD27 ----
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df["Longitud"], df["Latitud"]),
    crs="EPSG:4267"   # NAD27 geográficas
)
# 2. Reproyectar directo a WGS84 UTM zona 13N
gdf_utm = gdf.to_crs("EPSG:32613")

print(gdf_utm.crs)
# Out:
# EPSG:32613

# %% [markdown]
# ### <span style="color:#cc416d"> Límite del acuífero. proyección</span>

# %%
# 📥 Leer shapefile con Pandas
gdf_lim = gpd.read_file('C:/Proyectos/2025/Armeria/aol.shp')
print (gdf_lim.crs)
# Out:
# EPSG:4267

# %%
# 🔄 Reproyectar a UTM WGS84 zona 13N
gdf_lim_utm = gdf_lim.to_crs("EPSG:32613")

print(gdf_lim_utm.crs)  # EPSG:32613
# Out:
# EPSG:32613

# %% [markdown]
# ### <span style="color:#cc416d"> Años interpolados </span>

# %%
anios = ['1996', '1998', '2000', '2001', '2003', '2004', '2005', '2006', '2008', '2010', '2015']
print ("\U0001F40D")
# Out:
# 🐍

# %% [markdown]
# ###  <span style="color:#cc416d"> Coordenadas del limite del acuífero </span>

# %%
minx, miny, maxx, maxy = gdf_lim_utm.total_bounds
print("Bounds en NAD27 (°):", gdf_lim.total_bounds)
print("Bounds en WGS84 UTM 13N (m):", gdf_lim_utm.total_bounds)
# Out:
# Bounds en NAD27 (°): [-104.0930256    18.68470573 -103.69861603   19.29588507]
# Bounds en WGS84 UTM 13N (m): [ 595337.87057392 2066485.25853548  637134.0457093  2133968.430342  ]

# %%
# 1) bounds del polígono reproyectado (¡en UTM!)
minx, miny, maxx, maxy = map(float, gdf_lim_utm.total_bounds)
print("Bounds límite UTM:", minx, miny, maxx, maxy)
# Out:
# Bounds límite UTM: 595337.8705739178 2066485.2585354783 637134.045709303 2133968.430342003

# %% [markdown]
# ###  <span style="color:#cc416d"> Resolución de la imagen</span>

# %%
res = 500  # metros/píxel
print ("\U0001F40D")
# Out:
# 🐍

# %%
for anio in anios:
    campo_valor = str(anio)

    # Toma SOLO filas con valor numérico
    mask = (
        gdf_utm[campo_valor].notna() &
        np.isfinite(gdf_utm[campo_valor])
    )
    sub = gdf_utm.loc[mask, [campo_valor, "geometry"]].copy()

    if len(sub) < 3:
        print(f"⚠️ Solo {len(sub)} valores válidos para {campo_valor}, se omite.")
        continue

    # Coordenadas UTM desde la geometría (en metros)
    sub["X"] = sub.geometry.x
    sub["Y"] = sub.geometry.y
    
    # Bounds de puntos (diagnóstico)
    xx = sub["X"].to_numpy()
    yy = sub["Y"].to_numpy()
    print(f"🧭 {campo_valor}  puntos={len(sub)}  "
          f"X[{xx.min():.1f},{xx.max():.1f}]  Y[{yy.min():.1f},{yy.max():.1f}]")


       
    # Renombrar Z a un nombre sin espacios
    col_z = f"val_{campo_valor}"
    sub = sub.rename(columns={campo_valor: col_z})

    # CSV temporal SOLO con X,Y,Z en metros
    temp_csv = os.path.join(carpeta_salida, f"temp_{campo_valor}.csv")
    sub[["X", "Y", col_z]].to_csv(temp_csv, index=False)

    salida_raster = os.path.join(carpeta_salida, f"nivelAOL_{campo_valor}.tif")

    # gdal_grid completamente coherente en UTM
    comando = [
        "gdal_grid",
        "-a", "invdist:power=2.0:smoothing=0.0",
        "-txe", str(minx), str(maxx),
        "-tye", str(miny), str(maxy),        # ymin, ymax
        "-tr",  str(res), str(res),          # p.ej. 500 m
        "-zfield", col_z,
        "-oo", "X_POSSIBLE_NAMES=X",
        "-oo", "Y_POSSIBLE_NAMES=Y",
        # "-a_srs", "EPSG:32613",
        "-a_srs", "+proj=utm +zone=13 +datum=WGS84 +units=m +no_defs",              # no necesita leer la entrada EPSG del proj.db.
        "-ot", "Float32",
        "-of", "GTiff",
        f"CSV:{temp_csv}",
        salida_raster
    ]

    print(f"🔹 Ejecutando: {' '.join(comando)}")
    result = subprocess.run(comando, capture_output=True, text=True)

    if result.returncode != 0:
        print(f"⚠️ Error con {campo_valor}")
        print("STDOUT:", result.stdout.strip())
        print("STDERR:", result.stderr.strip())
    else:
        print(f"✅ Guardado: {salida_raster}")
print ("\U0001F40D")
# Out:
# 🧭 1996  puntos=23  X[610399.2,628228.5]  Y[2077698.2,2100167.7]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_1996 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_1996.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_1996.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_1996.tif
# 🧭 1998  puntos=26  X[610399.2,634029.0]  Y[2074887.1,2100167.7]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_1998 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_1998.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_1998.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_1998.tif
# 🧭 2000  puntos=31  X[602237.7,628228.5]  Y[2077698.2,2100167.7]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2000 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2000.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2000.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2000.tif
# 🧭 2001  puntos=18  X[613487.8,628228.5]  Y[2077698.2,2094706.6]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2001 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2001.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2001.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2001.tif
# 🧭 2003  puntos=30  X[602237.7,628228.5]  Y[2077698.2,2100167.7]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2003 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2003.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2003.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2003.tif
# 🧭 2004  puntos=25  X[610399.2,634029.0]  Y[2077698.2,2100167.7]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2004 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2004.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2004.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2004.tif
# 🧭 2005  puntos=27  X[610399.2,634029.0]  Y[2077698.2,2100167.7]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2005 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2005.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2005.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2005.tif
# 🧭 2006  puntos=34  X[602237.7,634029.0]  Y[2077698.2,2100167.7]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2006 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2006.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2006.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2006.tif
# 🧭 2008  puntos=59  X[602237.7,634029.0]  Y[2074887.1,2123745.6]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2008 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2008.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2008.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2008.tif
# 🧭 2010  puntos=15  X[602237.7,628228.5]  Y[2077698.2,2100011.6]
# 🔹 Ejecutando: gdal_grid -a invdist:power=2.0:smoothing=0.0 -txe 595337.8705739178 637134.045709303 -tye 2066485.2585354783 2133968.430342003 -tr 500 500 -zfield val_2010 -oo X_POSSIBLE_NAMES=X -oo Y_POSSIBLE_NAMES=Y -a_srs +proj=utm +zone=13 +datum=WGS84 +units=m +no_defs -ot Float32 -of GTiff CSV:C:/Proyectos/2025/Armeria/salidas/temp_2010.csv C:/Proyectos/2025/Armeria/salidas/nivelAOL_2010.tif
# ✅ Guardado: C:/Proyectos/2025/Armeria/salidas/nivelAOL_2010.tif
# ⚠️ Solo 2 valores válidos para 2015, se omite.
# 🐍

# %% [markdown]
# ###  <span style="color:#cc416d"> Para cuando se quiere hacer un buffer al limte del AOL</span>

# %%
buffer_m = 1
buff_m = str (buffer_m)
# 3) Bounds del buffer
minx, miny, maxx, maxy = gdf_limite.buffer(buffer_m).total_bounds
print("Bounds con buffer:", minx, miny, maxx, maxy)  # <-- verifica que cambian
res = 500  # metros/píxel


print ("\U0001F40D")

# %% [markdown]
# Las coordenadas deben de ser las mismas solo que con los metros de más

# %%
imga = os.path.join(carpeta_salida, "nivelAOL_1996.tif") 
with rasterio.open(imga) as src:
    arr = src.read(1, masked=True)
    print("dtype:", src.dtypes[0], "nodata:", src.nodata)
    vals = arr.compressed()
    print("min:", vals.min(), "max:", vals.max())
# Out:
# dtype: float32 nodata: None
# min: 2.3135822 max: 48.359707
